# %% [markdown]
# This notebook computes the Icing Days index: starting from the daily maximum temperature (1980-1990),
# the Icing Days index is the number of days where TX < 0°C

# %% [markdown]
# Connect to the remote ECAS instance

# %%
from PyOphidia import cube
cube.Cube.setclient(read_env=True)

# %% [markdown]
# Import source data (maximum temperature °K)

# %%
maxtemp = cube.Cube(src_path='/data-training/E63_kp40_198001_199012_T2m_daymax_merged.nc',
    measure='temp2',
    import_metadata='yes',
    imp_dim='time',
    imp_concept_level='d', vocabulary='CF',hierarchy='oph_base|oph_base|oph_time',
    ncores=4,
    description='Max Temps'
    )

# %% [markdown]
# Identify the icing days

# %%
icingdays = maxtemp.apply(
    query="oph_predicate('OPH_FLOAT','OPH_INT',measure,'x-273.15','<0','1','0')"
)

# %% [markdown]
# Count the number of icing days

# %%
count = icingdays.reduce2(
    operation='sum',
    dim='time',
    concept_level='y',
)

# %% [markdown]
# Plot the result

# %%
firstyear = count.subset(subset_filter=1, subset_dims='time')

# %%
data = firstyear.export_array(show_time='yes')
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap, cm
import numpy as np

lat = data['dimension'][0]['values'][:]
lon = data['dimension'][1]['values'][:]
var = data['measure'][0]['values'][:]
var = np.reshape(var, (len(lat), len(lon)))

fig = plt.figure(figsize=(15, 15), dpi=100)
ax  = fig.add_axes([0.1,0.1,0.8,0.8])

map = Basemap(projection='cyl',llcrnrlat= -90,urcrnrlat= 90, llcrnrlon=0,urcrnrlon=360, resolution='c')

map.drawcoastlines()
map.drawparallels(np.arange( -90, 90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(-180,180,30),labels=[0,0,0,1])

x, y = map(*np.meshgrid(lon,lat))

clevs = np.arange(0,371,10)

cnplot = map.contourf(x,y,var,clevs,cmap=plt.cm.jet)
cbar = map.colorbar(cnplot,location='right')

plt.title('Icing Days (year 1980)')
plt.show()

# %% [markdown]
# To clear your workspace before running other notebooks

# %%
cube.Cube.client.submit("oph_delete cube=[container=E63_kp40_198001_199012_T2m_daymax_merged.nc]")
cube.Cube.deletecontainer(container='E63_kp40_198001_199012_T2m_daymax_merged.nc')
